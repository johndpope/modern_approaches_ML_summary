# %%
import numpy as np
import numpy.random as rnd
import time


def extend( A ):

    A = np.hstack(
        (A, np.zeros( (A.shape[0],1) ))
    ); A = np.vstack(
        (A, np.array( (0.0,)*(A.shape[1]-1) + (1.0,), ndmin=2 ))
    )

    return A


def downdateEx( A ):

    p = A.shape[ 0 ]
    q = A.shape[ 1 ]
    r = min( p, q )

    D = A[ :, -1 ]; D = D.reshape( p, 1 )

    # retrieve a first SVD representation
    U, s, Vt = np.linalg.svd( A, full_matrices=False )

    Q1, R1 = np.linalg.qr( 
        np.dot(
            np.dot( U, U.T ) - np.identity( p ),
            D
        )
    )

    Q2, R2 = np.linalg.qr(
        np.dot(
            np.identity( q ) - np.dot( Vt.T, Vt ),
            np.vstack(
                (np.zeros( (q-D.shape[1], D.shape[1] ) ),
                np.identity( D.shape[1] ))
            )
        )
    )

    l = D.shape[ 1 ]

    Q1p = Q1[ :, :l ]
    Q2p = Q2[ :, :l ]

    R1p = R1[ :l, : ]
    R2p = R2[ :l, : ]


    K = np.dot(

        np.vstack((
            -np.dot( U.T, D ),
            R1p
        )),

        np.hstack((
            np.dot(
                np.hstack((
                    np.zeros(( l, q-l )),
                    np.identity( l )
                )),
                Vt.T
            ),
            np.transpose( R2p )
        ))

    )

    K = K + np.diag( np.append( s, 0 ) )

    Uk, sk, Vtk = np.linalg.svd( K, full_matrices=False )


    Ud = np.dot(
        np.hstack((
            U,
            Q1p
        )),
        Uk
    )

    sd = sk
    sd[ abs( sd ) < 1.0e-10 ] = 0

    Vd = np.dot(
        np.hstack((
            Vt.T, Q2p
        )),
        Vtk.T
    )

    Vd = Vd[ :q-l, : ]
    Vdt = np.transpose( Vd )

    
    nm = Ud.shape[ 0 ]
    nn = Vdt.shape[ 1 ]
    nr = min( nm, nn )

    Ud = Ud[ :, :nr ]
    sd = sd[ :nr ]
    Vdt = Vdt[ :nr, : ]
    
    
    return Ud, sd, Vdt



class iSVD( object ):

    def __init__( self, inU, ins, inVt, updateVt = False ):

        self.m, self.n = inU.shape[ 0 ], inVt.shape[ 1 ]
        self.U, self.iU, self.s, self.iVt, self.Vt = inU, None, ins, None, inVt

        self.iVpsinv = None
        self.updateVt = updateVt

        
        
    def update( self, data ):
        
        a = data.reshape( data.shape[0], )
                
        # m = {U^T} a / m = U'^T {U^T} a (if U' is defined)
        mv = np.dot( self.U.T, a )
        if not self.iU is None:
            mv = np.dot( self.iU.T, mv )
        
        
        # assuming the rank does not increase, verifying below
        rankIncreasingUpdate = False
        
        if self.n < self.m:
            
            # p = a - Um / p = a - U U'm (if U' is defined)
            if self.iU is None:
                p = a - np.dot( self.U, mv )
            else:
                p = a -  np.dot( self.U, np.dot( self.iU, mv ) )
            
            # Ra = \| p \|_{2}
            Ra = np.linalg.norm( p, ord = 2 )
            
            # verify if the column is from the same subspace
            epsilon = np.sqrt( np.finfo(np.float64).eps * self.m**2 * self.n * 10*2 )                        
            if ( np.abs( Ra ) > epsilon ):
                rankIncreasingUpdate = True
        
        
        if rankIncreasingUpdate == False:

            # construct svd-decomposition (update s directly)
            C, self.s, Dt = self.diagUpdate( self.s, mv, column=False )

            # U' = C / U' = U'C (if U' is defined)
            if self.iU is None:
                self.iU = C
            else:
                self.iU = np.dot( self.iU, C )

            # if it was specified that V^T should be updated
            if self.updateVt:
                                
                r = Dt.shape[ 1 ]
                W = Dt[ 0:r, : ]
                w = Dt[ r, : ]; w.shape = ( 1, w.shape[0] )
                
                # \|w\|^2 - squared norm
                wnrmsq = np.linalg.norm( w, ord=2 )**2
                # W^{+} = W^T + \frac{ w^T }{ 1-\|w\|^2 }\(wW^T\)
                Wpsinv = W.T + np.dot( (1/(1-wnrmsq))*w.T, np.dot( w, W.T ) )
                del r, wnrmsq

                # V'_{new} = V'_{old} W (note: using the transposes below which,
                # in turn, gives the following form: V'^T_{new} = W^T V'^T_{old}
                if not self.iVt is None:
                    self.iVt = np.dot( W.T, self.iVt )
                else:
                    self.iVt = W.T

                # (V'^{+})_{new} = W^{+} (V'^{+})_{old}
                if not self.iVpsinv is None:
                    self.iVpsinv = np.dot( Wpsinv, self.iVpsinv )
                else:
                    self.iVpsinv = Wpsinv

                # V_{new} = \begin{bmatrix} V_{old} \\ w(V'^{+})_{new} \end{bmatrix}
                self.Vt = np.hstack( (self.Vt, np.dot( self.iVpsinv.T, w.T) ) )

                del w, Wpsinv, W
        
        if rankIncreasingUpdate == True:
        
            # adding a trailing 0 (0 column and a 0 row via diag.)
            S = np.concatenate( ( self.s, (0.0,) ) )
            mv = np.concatenate( ( mv, (Ra,) ) )

            C, self.s, Dt = self.diagUpdate( S, mv, column=True)

            self.U = np.hstack( (self.U, p[ :, np.newaxis ] / Ra) )
        
            if self.iU is None:
                self.iU = C
            else:
                self.iU = extend( self.iU )
                self.iU = np.dot( self.iU, C )

                
            if self.updateVt:
                self.Vt = extend( self.Vt )
                if not self.iVt is None:
                    self.iVt = np.dot( Dt.T, extend(self.iVt) )
                else:
                    self.iVt = Dt.T

                if not self.iVpsinv is None:
                    self.iVpsinv = np.dot( Dt.T, extend( self.iVpsinv ) )
                else:
                    self.iVpsinv = Dt.T
        
        self.n = self.Vt.shape[ 1 ]



    def downdate( self, k ):
        
        Ux, sx, Vtx = self.svd()
        A = np.dot( Ux, np.dot( np.diag(sx), Vtx ) )
        
        Af = A.copy()
        Af[ :, :Af.shape[1]-1 ] = A[ :, 1: ]
        
        self.U, self.s, self.Vt = downdateEx( Af )        

        self.iVpsinv = None
        
        self.iU = None
        self.iVt = None
        
        self.iVpsinv = None        
        self.n = self.Vt.shape[ 1 ]        
        
        

    def diagUpdate( self, sigmas, mv, column = True ):

        if column == False:

            nv = np.copy( mv )
            nv = nv.reshape( nv.shape[ 0 ], 1 )

            K = np.hstack( ( np.diag( sigmas ), nv  ) )
        else:

            K = np.diag( sigmas )
            K[ :, -1 ] = mv

        Ux, sx, Vtx = np.linalg.svd( K, full_matrices=False )
        return Ux, sx, Vtx.T
        

    def svd( self ):

        if not self.iU is None:
            Ux = np.dot( self.U, self.iU )
        else:
            Ux = self.U

        if self.updateVt:
            if not self.iVt is None:
                Vtx = np.dot( self.iVt, self.Vt )
            else:
                Vtx = self.Vt
        else:
            Vtx = None

        return Ux, self.s.copy(), Vtx

    
    
    def esvd( self ):
        return self.U, self.iU, self.s, self.iVt, self.Vt
    
    

    def orthogonalize( self ):

        if not self.iU is None:
            
            Usvd, ssvd, Vsvd = np.linalg.svd( 
                np.dot( self.iU, np.diag( self.s ) ), full_matrices=False, compute_uv=True 
            )

            self.U = np.dot( self.U, Usvd ); self.iU = None
            self.s = ssvd

            if self.updateVt:                
                
                self.Vt = np.dot( np.dot( Vsvd, self.iVt), self.Vt )
                self.iVt = None; self.iVpsinv = None
                
                return self.U, self.s, self.Vt
            else:
                return self.U, self.s, None
        else:
            pass

# %%
def test_SVD_updater():
    """
    Testinf function for iSVD class.
    """

    increaseRank = False

    if increaseRank:
    
        # Test column update. Thin matrix, rank increases
        n_rows = 1000; n_cols = 800
        A = rnd.rand(n_rows,n_cols)
        (U,S,Vh) = np.linalg.svd( A , full_matrices=False, compute_uv=True )
        
        a1 = rnd.rand(n_rows,1)
        A = np.hstack( (A,a1) )
        (Ut1,St1,Vht1) = np.linalg.svd( A  , full_matrices=False, compute_uv=True)

        print ( "START TEST 1 -------------------------------" );
        SVD_upd = iSVD( U,S,Vh, updateVt = True)        

        SVD_upd.update(a1 )
        (Us1, Ss1, Vhs1) = SVD_upd.svd()

        
        

        
        Ar1 = np.dot( Us1, np.dot(np.diag(Ss1), Vhs1 ) )
        print ( "END TEST 1 -------------------------------" );        
        diff1 = np.max( np.abs( A - Ar1) )/St1[0]
        print( np.allclose( A, Ar1 ) )
        
        a2 = rnd.rand(n_rows,1)
        A = np.hstack( (A,a2) )
        
        print ( "START TEST 2 -------------------------------" );
        SVD_upd.update( a2 )
        (Us2, Ss2, Vhs2) = SVD_upd.svd()
        
        Ar2 = np.dot( Us2, np.dot(np.diag(Ss2), Vhs2 ) )
        print ( "END TEST 2 -------------------------------" );
        diff2 = np.max( np.abs( A - Ar2) )/St1[0]
        print( np.allclose( A, Ar2 ) )
        
    else:

        #Test column update. Thin matrix, rank not increases
        n_rows = 1000; n_cols = 800
        A = rnd.rand(n_rows,n_cols)
        (U,S,Vh) = np.linalg.svd( A , full_matrices=False, compute_uv=True )
        
        ##a1 = rnd.rand(5,1)
        a1 = np.dot(A, rnd.rand(n_cols,1) )
        A = np.hstack( (A,a1) )
        (Ut,St,Vht) = np.linalg.svd( A  , full_matrices=False, compute_uv=True)
        

        print ( "START TEST 1 -------------------------------" );
        SVD_upd = iSVD( U,S,Vh, updateVt = True)
        SVD_upd.update( a1 )
        ( Us1, Ss1, Vhs1) = SVD_upd.svd()

        Ar1 = np.dot( Us1, np.dot(np.diag(Ss1), Vhs1 ) )
        
        diff1 = np.max( np.abs( A - Ar1) )/St[0]
        print ( "END TEST 1 -------------------------------" );
        print( np.allclose( A, Ar1 ) )

        
        
        print ( "START TEST 2 -------------------------------" );
        a2 = rnd.rand(n_rows,1)
        
        #a2 = np.dot(A, np.array([2,1,4,-3],ndmin=2 ).T )
        A = np.hstack( (A,a2) )
        (Ut,St,Vht) = np.linalg.svd( A  , full_matrices=False, compute_uv=True)
        SVD_upd.update( a2 )
        (Us2, Ss2, Vhs2) = SVD_upd.svd()

        
        Ar2 = np.dot( Us2, np.dot(np.diag(Ss2), Vhs2 ) )
        print ( "END TEST 2 -------------------------------" );        
        print( np.allclose( A, Ar2 ) )
        
        diff2 = np.max( np.abs( A - Ar2) )/St[0]

    print( diff2 )
    return diff2

test_SVD_updater()
# Out:
# START TEST 1 -------------------------------
# END TEST 1 -------------------------------
# True
# START TEST 2 -------------------------------
# END TEST 2 -------------------------------
# True
# 5.184871238317548e-15
# 5.184871238317548e-15

# %%
p = 50; q = 100;
r = min( p, q )

# construct a random matrix of size m, n
#X = np.random.randn( p, q ) + 1j*np.random.randn( p, q )
X = np.random.randn( p, q )

U, S, Vh = np.linalg.svd( X, full_matrices=False )

isvd = iSVD( U, S, Vh, updateVt = True  )

# construct a random update vector
#a = np.random.randn( p, 1 ) + 1j*np.random.randn( p, 1 )
a = np.random.randn( p, 1 )

isvd.update( a )
(Un, Sn, Vhn ) = isvd.svd()

# %%
b = np.zeros( (q+1,1) ); b[ q ] = 1
Aab = np.append( X, np.zeros( (p,1), dtype=complex), axis=1  ) + np.dot( a, np.transpose(b) )

X = Aab

Sp = np.diag( isvd.s )
Ai = np.dot( Un, np.dot(np.diag(Sn), Vhn ) )


Aix = np.dot( isvd.U, isvd.iU)
Aix = np.dot( Aix, np.diag(isvd.s) )
Aix = np.dot( Aix, np.dot(isvd.iVt, isvd.Vt) )

print( Aab.shape,Ai.shape )
print( np.allclose( Aab, Ai ) )
print( np.allclose( Aab, Aix ) )


q = q-2
Aab = Aab[ :, 1: ]
isvd.downdate( 0 )
Aab = Aab[ :, 1: ]
isvd.downdate( 0 )

# Aix = np.dot( isvd.U, isvd.iU)
# Aix = np.dot( Aix, np.diag(isvd.s) )
# Aix = np.dot( Aix, np.dot(isvd.iVt, isvd.Vt) )

Aix = np.dot( isvd.U, np.dot( np.diag( isvd.s ), isvd.Vt ))

print( np.allclose( Aab, Aix ) )
# Out:
# (50, 101) (50, 101)
# True
# True
# True

# %%
import time

t0a = time.time()


for i in range(0, 300 ):
    
    a = np.random.randn( p, 1 )

    
    t0i = time.time()
    isvd.update( a )
    
    (Un, Sn, Vhn ) = (None, None, None)
    if (isvd.iU is None) or (isvd.iVt is None):
        Un, Sn, Vhn = isvd.svd()
    t1i = time.time()

    
    q = q+1

    b = np.zeros( (q+1,1) ); b[ q ] = 1
    Aab = np.append( Aab, np.zeros( (p,1), dtype=complex), axis=1  ) + np.dot( a, np.transpose(b) )

    
    t0 = time.time()
    Uab, sab, Vtab = np.linalg.svd( Aab, full_matrices=False )
    t1 = time.time()

    
    similar = True
    
    print( "Current index: ", i)
    print( "Incremental: ", (t1i-t0i), " Regular: ", (t1-t0))
    print( "Shape: ", Aab.shape )

    if not Un is None:
        Ai = np.dot( Un, np.dot( np.diag(Sn), Vhn ) )
        
        if np.allclose( Aab, Ai ) == False:
            similar = False
        print( "Aab vs Ai: ", similar )

    if Un is None:
        Aix = np.dot( isvd.U, isvd.iU)
        Aix = np.dot( Aix, np.diag(isvd.s) )
        Aix = np.dot( Aix, np.dot(isvd.iVt, isvd.Vt) )

        if np.allclose( Aab, Aix ) == False:
            similar = False
        print( "Aab vs Aix: ", similar )
    print( "---------------------------------\n" )
    
    if i % 100 == 0:
        t1a = time.time()
        print( "Iteration: ", i, Aab.shape, " ", (t1a-t0a), "s" )
        
        if Un is None:
            print( "        ", isvd.U.shape, isvd.iU.shape, isvd.s.shape, isvd.iVt.shape, isvd.Vt.shape, "\n" )

            
    if i > 0 and i % 5 == 0 and np.random.randn(1) < 0.5:
        isvd.downdate( 0 )
        Aab = Aab[ :, 1: ]

        q = q-1 
        
        (Un, Sn, Vhn ) = (None, None, None)
        if (isvd.iU is None) or (isvd.iVt is None):
            Un, Sn, Vhn = isvd.svd()
        
        if not Un is None:
            Ai = np.dot( Un, np.dot( np.diag(Sn), Vhn ) )

            if np.allclose( Aab, Ai ) == False:
                similar = False
            print( "DOWNDATE Aab vs Ai: ", similar )

        if Un is None:
            Aix = np.dot( isvd.U, isvd.iU)
            Aix = np.dot( Aix, np.diag(isvd.s) )
            Aix = np.dot( Aix, np.dot(isvd.iVt, isvd.Vt) )

            if np.allclose( Aab, Aix ) == False:
                similar = False
            print( "DOWNDATE Aab vs Aix: ", similar )
            
            
            
    if similar == False:
        print( "Current index: ", i)
        print( "Shape: ", Aab.shape )
        
        print( (((Aab - Aix) **2) **0.5).mean() )
        
        break;

        
t1a = time.time()
print( "Overall time: ", (t1a-t0a) )
# Out:
# Current index:  0
# Incremental:  0.0008389949798583984  Regular:  0.0031409263610839844
# Shape:  (50, 100)
# Aab vs Aix:  True
# ---------------------------------
#
# Iteration:  0 (50, 100)   0.005399227142333984 s
#          (50, 50) (50, 50) (50,) (50, 50) (50, 100)
#
# Current index:  1
# Incremental:  0.000988006591796875  Regular:  0.0021996498107910156
# Shape:  (50, 101)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  2
# Incremental:  0.001033782958984375  Regular:  0.002145051956176758
# Shape:  (50, 102)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  3
# Incremental:  0.00096893310546875  Regular:  0.0028061866760253906
# Shape:  (50, 103)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  4
# Incremental:  0.0009598731994628906  Regular:  0.0021550655364990234
# Shape:  (50, 104)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  5
# Incremental:  0.0010149478912353516  Regular:  0.0028007030487060547
# Shape:  (50, 105)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  6
# Incremental:  0.0007939338684082031  Regular:  0.0018889904022216797
# Shape:  (50, 105)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  7
# Incremental:  0.0009219646453857422  Regular:  0.001870870590209961
# Shape:  (50, 106)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  8
# Incremental:  0.0008881092071533203  Regular:  0.0018291473388671875
# Shape:  (50, 107)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  9
# Incremental:  0.0009551048278808594  Regular:  0.0025730133056640625
# Shape:  (50, 108)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  10
# Incremental:  0.0008759498596191406  Regular:  0.0020301342010498047
# Shape:  (50, 109)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  11
# Incremental:  0.0008990764617919922  Regular:  0.0018680095672607422
# Shape:  (50, 109)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  12
# Incremental:  0.0010378360748291016  Regular:  0.0026197433471679688
# Shape:  (50, 110)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  13
# Incremental:  0.0009410381317138672  Regular:  0.0019998550415039062
# Shape:  (50, 111)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  14
# Incremental:  0.0010929107666015625  Regular:  0.0021300315856933594
# Shape:  (50, 112)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  15
# Incremental:  0.0009708404541015625  Regular:  0.00286102294921875
# Shape:  (50, 113)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  16
# Incremental:  0.0009570121765136719  Regular:  0.002048015594482422
# Shape:  (50, 113)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  17
# Incremental:  0.0010111331939697266  Regular:  0.00201416015625
# Shape:  (50, 114)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  18
# Incremental:  0.0009238719940185547  Regular:  0.0020551681518554688
# Shape:  (50, 115)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  19
# Incremental:  0.0008671283721923828  Regular:  0.0026650428771972656
# Shape:  (50, 116)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  20
# Incremental:  0.0011129379272460938  Regular:  0.0020761489868164062
# Shape:  (50, 117)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  21
# Incremental:  0.0009531974792480469  Regular:  0.002833127975463867
# Shape:  (50, 118)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  22
# Incremental:  0.0009031295776367188  Regular:  0.001934051513671875
# Shape:  (50, 119)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  23
# Incremental:  0.0009860992431640625  Regular:  0.002023935317993164
# Shape:  (50, 120)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  24
# Incremental:  0.0008380413055419922  Regular:  0.0027048587799072266
# Shape:  (50, 121)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  25
# Incremental:  0.0009791851043701172  Regular:  0.0020339488983154297
# Shape:  (50, 122)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  26
# Incremental:  0.0007691383361816406  Regular:  0.0020761489868164062
# Shape:  (50, 122)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  27
# Incremental:  0.0009429454803466797  Regular:  0.002293825149536133
# Shape:  (50, 123)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  28
# Incremental:  0.0009288787841796875  Regular:  0.0019888877868652344
# Shape:  (50, 124)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  29
# Incremental:  0.0009815692901611328  Regular:  0.0019218921661376953
# Shape:  (50, 125)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  30
# Incremental:  0.0009138584136962891  Regular:  0.0022149085998535156
# Shape:  (50, 126)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  31
# Incremental:  0.0008933544158935547  Regular:  0.0021140575408935547
# Shape:  (50, 127)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  32
# Incremental:  0.001013040542602539  Regular:  0.0022568702697753906
# Shape:  (50, 128)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  33
# Incremental:  0.0009479522705078125  Regular:  0.001968860626220703
# Shape:  (50, 129)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  34
# Incremental:  0.0009801387786865234  Regular:  0.001950979232788086
# Shape:  (50, 130)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  35
# Incremental:  0.0009968280792236328  Regular:  0.0022993087768554688
# Shape:  (50, 131)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  36
# Incremental:  0.0007402896881103516  Regular:  0.001967191696166992
# Shape:  (50, 131)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  37
# Incremental:  0.0009500980377197266  Regular:  0.0020401477813720703
# Shape:  (50, 132)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  38
# Incremental:  0.000888824462890625  Regular:  0.002228975296020508
# Shape:  (50, 133)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  39
# Incremental:  0.0008490085601806641  Regular:  0.0019719600677490234
# Shape:  (50, 134)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  40
# Incremental:  0.0008537769317626953  Regular:  0.002057790756225586
# Shape:  (50, 135)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  41
# Incremental:  0.0007739067077636719  Regular:  0.0020089149475097656
# Shape:  (50, 135)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  42
# Incremental:  0.0009229183197021484  Regular:  0.002213716506958008
# Shape:  (50, 136)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  43
# Incremental:  0.0008871555328369141  Regular:  0.002214193344116211
# Shape:  (50, 137)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  44
# Incremental:  0.0009508132934570312  Regular:  0.0020668506622314453
# Shape:  (50, 138)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  45
# Incremental:  0.0008976459503173828  Regular:  0.0026178359985351562
# Shape:  (50, 139)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  46
# Incremental:  0.0007233619689941406  Regular:  0.002195119857788086
# Shape:  (50, 139)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  47
# Incremental:  0.0010139942169189453  Regular:  0.0020952224731445312
# Shape:  (50, 140)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  48
# Incremental:  0.0010650157928466797  Regular:  0.0023627281188964844
# Shape:  (50, 141)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  49
# Incremental:  0.000926971435546875  Regular:  0.002501964569091797
# Shape:  (50, 142)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  50
# Incremental:  0.0010628700256347656  Regular:  0.0024530887603759766
# Shape:  (50, 143)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  51
# Incremental:  0.0009417533874511719  Regular:  0.002330303192138672
# Shape:  (50, 143)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  52
# Incremental:  0.001123189926147461  Regular:  0.002638101577758789
# Shape:  (50, 144)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  53
# Incremental:  0.001129150390625  Regular:  0.002501249313354492
# Shape:  (50, 145)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  54
# Incremental:  0.0012481212615966797  Regular:  0.0029449462890625
# Shape:  (50, 146)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  55
# Incremental:  0.0012669563293457031  Regular:  0.0024759769439697266
# Shape:  (50, 147)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  56
# Incremental:  0.0011587142944335938  Regular:  0.002512216567993164
# Shape:  (50, 148)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  57
# Incremental:  0.0010328292846679688  Regular:  0.0027229785919189453
# Shape:  (50, 149)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  58
# Incremental:  0.0011279582977294922  Regular:  0.0025589466094970703
# Shape:  (50, 150)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  59
# Incremental:  0.0010211467742919922  Regular:  0.002814054489135742
# Shape:  (50, 151)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  60
# Incremental:  0.001428842544555664  Regular:  0.003002166748046875
# Shape:  (50, 152)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  61
# Incremental:  0.0014178752899169922  Regular:  0.0029358863830566406
# Shape:  (50, 153)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  62
# Incremental:  0.0012359619140625  Regular:  0.003145933151245117
# Shape:  (50, 154)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  63
# Incremental:  0.0014672279357910156  Regular:  0.003882169723510742
# Shape:  (50, 155)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  64
# Incremental:  0.0011811256408691406  Regular:  0.002908945083618164
# Shape:  (50, 156)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  65
# Incremental:  0.0016489028930664062  Regular:  0.003195047378540039
# Shape:  (50, 157)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  66
# Incremental:  0.0012581348419189453  Regular:  0.002593994140625
# Shape:  (50, 158)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  67
# Incremental:  0.0013041496276855469  Regular:  0.0032041072845458984
# Shape:  (50, 159)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  68
# Incremental:  0.001444101333618164  Regular:  0.0029938220977783203
# Shape:  (50, 160)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  69
# Incremental:  0.0012977123260498047  Regular:  0.002637147903442383
# Shape:  (50, 161)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  70
# Incremental:  0.0012629032135009766  Regular:  0.003400087356567383
# Shape:  (50, 162)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  71
# Incremental:  0.0009238719940185547  Regular:  0.0026159286499023438
# Shape:  (50, 162)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  72
# Incremental:  0.0014269351959228516  Regular:  0.0029549598693847656
# Shape:  (50, 163)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  73
# Incremental:  0.0013079643249511719  Regular:  0.0033218860626220703
# Shape:  (50, 164)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  74
# Incremental:  0.001313924789428711  Regular:  0.002949953079223633
# Shape:  (50, 165)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  75
# Incremental:  0.0014600753784179688  Regular:  0.002714872360229492
# Shape:  (50, 166)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  76
# Incremental:  0.0015659332275390625  Regular:  0.003905057907104492
# Shape:  (50, 166)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  77
# Incremental:  0.0013799667358398438  Regular:  0.003047943115234375
# Shape:  (50, 167)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  78
# Incremental:  0.0013279914855957031  Regular:  0.0027709007263183594
# Shape:  (50, 168)
# Aab vs Aix:  True
# ---------------------------------
# Current index:  79
# Incremental:  0.0011768341064453125  Regular:  0.0034780502319335938
# Shape:  (50, 169)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  80
# Incremental:  0.0014581680297851562  Regular:  0.0036928653717041016
# Shape:  (50, 170)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  81
# Incremental:  0.0013308525085449219  Regular:  0.0029990673065185547
# Shape:  (50, 170)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  82
# Incremental:  0.0013780593872070312  Regular:  0.0028717517852783203
# Shape:  (50, 171)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  83
# Incremental:  0.0012898445129394531  Regular:  0.0035858154296875
# Shape:  (50, 172)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  84
# Incremental:  0.0011091232299804688  Regular:  0.0030651092529296875
# Shape:  (50, 173)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  85
# Incremental:  0.001528024673461914  Regular:  0.0032668113708496094
# Shape:  (50, 174)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  86
# Incremental:  0.0011277198791503906  Regular:  0.0030260086059570312
# Shape:  (50, 175)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  87
# Incremental:  0.0011801719665527344  Regular:  0.0029637813568115234
# Shape:  (50, 176)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  88
# Incremental:  0.0012848377227783203  Regular:  0.003245115280151367
# Shape:  (50, 177)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  89
# Incremental:  0.0015399456024169922  Regular:  0.0027909278869628906
# Shape:  (50, 178)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  90
# Incremental:  0.0011448860168457031  Regular:  0.003350973129272461
# Shape:  (50, 179)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  91
# Incremental:  0.001024007797241211  Regular:  0.0030760765075683594
# Shape:  (50, 179)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  92
# Incremental:  0.0015838146209716797  Regular:  0.004293203353881836
# Shape:  (50, 180)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  93
# Incremental:  0.0013470649719238281  Regular:  0.003178834915161133
# Shape:  (50, 181)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  94
# Incremental:  0.0011970996856689453  Regular:  0.003113985061645508
# Shape:  (50, 182)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  95
# Incremental:  0.0015070438385009766  Regular:  0.003239870071411133
# Shape:  (50, 183)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  96
# Incremental:  0.0009169578552246094  Regular:  0.0030319690704345703
# Shape:  (50, 183)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  97
# Incremental:  0.001728057861328125  Regular:  0.003361225128173828
# Shape:  (50, 184)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  98
# Incremental:  0.0015251636505126953  Regular:  0.003795146942138672
# Shape:  (50, 185)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  99
# Incremental:  0.0011591911315917969  Regular:  0.003129243850708008
# Shape:  (50, 186)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  100
# Incremental:  0.0015742778778076172  Regular:  0.0036461353302001953
# Shape:  (50, 187)
# Aab vs Aix:  True
# ---------------------------------
#
# Iteration:  100 (50, 187)   0.5516879558563232 s
#          (50, 50) (50, 50) (50,) (50, 50) (50, 187)
#
# Current index:  101
# Incremental:  0.0011892318725585938  Regular:  0.002919912338256836
# Shape:  (50, 188)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  102
# Incremental:  0.0017750263214111328  Regular:  0.003545999526977539
# Shape:  (50, 189)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  103
# Incremental:  0.001706838607788086  Regular:  0.0041048526763916016
# Shape:  (50, 190)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  104
# Incremental:  0.0013811588287353516  Regular:  0.003072023391723633
# Shape:  (50, 191)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  105
# Incremental:  0.0014467239379882812  Regular:  0.0039670467376708984
# Shape:  (50, 192)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  106
# Incremental:  0.0012450218200683594  Regular:  0.0031960010528564453
# Shape:  (50, 192)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  107
# Incremental:  0.0012760162353515625  Regular:  0.0037789344787597656
# Shape:  (50, 193)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  108
# Incremental:  0.0010292530059814453  Regular:  0.003736734390258789
# Shape:  (50, 194)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  109
# Incremental:  0.0011682510375976562  Regular:  0.0038819313049316406
# Shape:  (50, 195)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  110
# Incremental:  0.001302957534790039  Regular:  0.0031251907348632812
# Shape:  (50, 196)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  111
# Incremental:  0.00144195556640625  Regular:  0.003492116928100586
# Shape:  (50, 197)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  112
# Incremental:  0.001664876937866211  Regular:  0.0034589767456054688
# Shape:  (50, 198)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  113
# Incremental:  0.001294851303100586  Regular:  0.0036368370056152344
# Shape:  (50, 199)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  114
# Incremental:  0.0013718605041503906  Regular:  0.003833293914794922
# Shape:  (50, 200)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  115
# Incremental:  0.0012829303741455078  Regular:  0.0031380653381347656
# Shape:  (50, 201)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  116
# Incremental:  0.0012879371643066406  Regular:  0.003053903579711914
# Shape:  (50, 202)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  117
# Incremental:  0.0018639564514160156  Regular:  0.003679037094116211
# Shape:  (50, 203)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  118
# Incremental:  0.001650094985961914  Regular:  0.003003835678100586
# Shape:  (50, 204)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  119
# Incremental:  0.0010571479797363281  Regular:  0.0036690235137939453
# Shape:  (50, 205)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  120
# Incremental:  0.0010900497436523438  Regular:  0.0034208297729492188
# Shape:  (50, 206)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  121
# Incremental:  0.0011379718780517578  Regular:  0.003340005874633789
# Shape:  (50, 207)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  122
# Incremental:  0.0015769004821777344  Regular:  0.003470182418823242
# Shape:  (50, 208)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  123
# Incremental:  0.001322031021118164  Regular:  0.003206014633178711
# Shape:  (50, 209)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  124
# Incremental:  0.0011818408966064453  Regular:  0.003953218460083008
# Shape:  (50, 210)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  125
# Incremental:  0.0010178089141845703  Regular:  0.0031960010528564453
# Shape:  (50, 211)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  126
# Incremental:  0.0008828639984130859  Regular:  0.0032739639282226562
# Shape:  (50, 211)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  127
# Incremental:  0.001251220703125  Regular:  0.003598928451538086
# Shape:  (50, 212)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  128
# Incremental:  0.0012159347534179688  Regular:  0.003756999969482422
# Shape:  (50, 213)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  129
# Incremental:  0.0013718605041503906  Regular:  0.003638029098510742
# Shape:  (50, 214)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  130
# Incremental:  0.0013358592987060547  Regular:  0.004520893096923828
# Shape:  (50, 215)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  131
# Incremental:  0.0009150505065917969  Regular:  0.0033271312713623047
# Shape:  (50, 215)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  132
# Incremental:  0.0015528202056884766  Regular:  0.00341033935546875
# Shape:  (50, 216)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  133
# Incremental:  0.0014519691467285156  Regular:  0.004036903381347656
# Shape:  (50, 217)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  134
# Incremental:  0.001558065414428711  Regular:  0.004364967346191406
# Shape:  (50, 218)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  135
# Incremental:  0.0012369155883789062  Regular:  0.0032320022583007812
# Shape:  (50, 219)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  136
# Incremental:  0.0010271072387695312  Regular:  0.003771066665649414
# Shape:  (50, 219)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  137
# Incremental:  0.0013821125030517578  Regular:  0.0033071041107177734
# Shape:  (50, 220)
# Aab vs Aix:  True
# ---------------------------------
# Current index:  138
# Incremental:  0.0012140274047851562  Regular:  0.004071950912475586
# Shape:  (50, 221)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  139
# Incremental:  0.0011281967163085938  Regular:  0.0031969547271728516
# Shape:  (50, 222)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  140
# Incremental:  0.001251220703125  Regular:  0.003936052322387695
# Shape:  (50, 223)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  141
# Incremental:  0.0020301342010498047  Regular:  0.003371000289916992
# Shape:  (50, 224)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  142
# Incremental:  0.0011477470397949219  Regular:  0.0031228065490722656
# Shape:  (50, 225)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  143
# Incremental:  0.0010759830474853516  Regular:  0.003900289535522461
# Shape:  (50, 226)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  144
# Incremental:  0.0011429786682128906  Regular:  0.0032379627227783203
# Shape:  (50, 227)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  145
# Incremental:  0.001255035400390625  Regular:  0.003812074661254883
# Shape:  (50, 228)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  146
# Incremental:  0.000997304916381836  Regular:  0.003107786178588867
# Shape:  (50, 228)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  147
# Incremental:  0.0010640621185302734  Regular:  0.0033919811248779297
# Shape:  (50, 229)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  148
# Incremental:  0.0012247562408447266  Regular:  0.0037488937377929688
# Shape:  (50, 230)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  149
# Incremental:  0.0013098716735839844  Regular:  0.003687143325805664
# Shape:  (50, 231)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  150
# Incremental:  0.0011518001556396484  Regular:  0.003300189971923828
# Shape:  (50, 232)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  151
# Incremental:  0.0010647773742675781  Regular:  0.0034699440002441406
# Shape:  (50, 232)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  152
# Incremental:  0.001405954360961914  Regular:  0.004127025604248047
# Shape:  (50, 233)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  153
# Incremental:  0.0012826919555664062  Regular:  0.0035016536712646484
# Shape:  (50, 234)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  154
# Incremental:  0.0012371540069580078  Regular:  0.0036008358001708984
# Shape:  (50, 235)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  155
# Incremental:  0.0012590885162353516  Regular:  0.004268169403076172
# Shape:  (50, 236)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  156
# Incremental:  0.0008919239044189453  Regular:  0.0034461021423339844
# Shape:  (50, 236)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  157
# Incremental:  0.0012030601501464844  Regular:  0.00379180908203125
# Shape:  (50, 237)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  158
# Incremental:  0.0012412071228027344  Regular:  0.00397801399230957
# Shape:  (50, 238)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  159
# Incremental:  0.0011670589447021484  Regular:  0.0037500858306884766
# Shape:  (50, 239)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  160
# Incremental:  0.0011599063873291016  Regular:  0.0034601688385009766
# Shape:  (50, 240)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  161
# Incremental:  0.0010349750518798828  Regular:  0.0037031173706054688
# Shape:  (50, 240)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  162
# Incremental:  0.001445770263671875  Regular:  0.0039217472076416016
# Shape:  (50, 241)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  163
# Incremental:  0.001210927963256836  Regular:  0.0033118724822998047
# Shape:  (50, 242)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  164
# Incremental:  0.001580953598022461  Regular:  0.0033648014068603516
# Shape:  (50, 243)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  165
# Incremental:  0.0013442039489746094  Regular:  0.00397801399230957
# Shape:  (50, 244)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  166
# Incremental:  0.001232147216796875  Regular:  0.003971099853515625
# Shape:  (50, 244)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  167
# Incremental:  0.0012938976287841797  Regular:  0.0037212371826171875
# Shape:  (50, 245)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  168
# Incremental:  0.001508951187133789  Regular:  0.004452705383300781
# Shape:  (50, 246)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  169
# Incremental:  0.001177072525024414  Regular:  0.0035009384155273438
# Shape:  (50, 247)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  170
# Incremental:  0.0012140274047851562  Regular:  0.0033752918243408203
# Shape:  (50, 248)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  171
# Incremental:  0.0015439987182617188  Regular:  0.004198312759399414
# Shape:  (50, 249)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  172
# Incremental:  0.001402139663696289  Regular:  0.0033941268920898438
# Shape:  (50, 250)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  173
# Incremental:  0.0012240409851074219  Regular:  0.004212141036987305
# Shape:  (50, 251)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  174
# Incremental:  0.0011141300201416016  Regular:  0.0037679672241210938
# Shape:  (50, 252)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  175
# Incremental:  0.0011072158813476562  Regular:  0.003314971923828125
# Shape:  (50, 253)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  176
# Incremental:  0.0010528564453125  Regular:  0.004305124282836914
# Shape:  (50, 253)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  177
# Incremental:  0.0011029243469238281  Regular:  0.004358053207397461
# Shape:  (50, 254)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  178
# Incremental:  0.0011098384857177734  Regular:  0.003940105438232422
# Shape:  (50, 255)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  179
# Incremental:  0.001394033432006836  Regular:  0.004377126693725586
# Shape:  (50, 256)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  180
# Incremental:  0.0015060901641845703  Regular:  0.004824161529541016
# Shape:  (50, 257)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  181
# Incremental:  0.0012478828430175781  Regular:  0.003536701202392578
# Shape:  (50, 257)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  182
# Incremental:  0.001390218734741211  Regular:  0.004155158996582031
# Shape:  (50, 258)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  183
# Incremental:  0.0018401145935058594  Regular:  0.004130840301513672
# Shape:  (50, 259)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  184
# Incremental:  0.0011811256408691406  Regular:  0.0038552284240722656
# Shape:  (50, 260)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  185
# Incremental:  0.001271963119506836  Regular:  0.004230976104736328
# Shape:  (50, 261)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  186
# Incremental:  0.0013971328735351562  Regular:  0.003919124603271484
# Shape:  (50, 262)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  187
# Incremental:  0.0012688636779785156  Regular:  0.0035779476165771484
# Shape:  (50, 263)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  188
# Incremental:  0.0011260509490966797  Regular:  0.004240989685058594
# Shape:  (50, 264)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  189
# Incremental:  0.001508951187133789  Regular:  0.0040318965911865234
# Shape:  (50, 265)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  190
# Incremental:  0.001190185546875  Regular:  0.003509044647216797
# Shape:  (50, 266)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  191
# Incremental:  0.0009527206420898438  Regular:  0.004148960113525391
# Shape:  (50, 266)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  192
# Incremental:  0.0015628337860107422  Regular:  0.005189180374145508
# Shape:  (50, 267)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  193
# Incremental:  0.0013399124145507812  Regular:  0.004724979400634766
# Shape:  (50, 268)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  194
# Incremental:  0.00131988525390625  Regular:  0.00510716438293457
# Shape:  (50, 269)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  195
# Incremental:  0.0012640953063964844  Regular:  0.004204988479614258
# Shape:  (50, 270)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  196
# Incremental:  0.0012569427490234375  Regular:  0.004068851470947266
# Shape:  (50, 271)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  197
# Incremental:  0.001435995101928711  Regular:  0.004606008529663086
# Shape:  (50, 272)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  198
# Incremental:  0.0011830329895019531  Regular:  0.0037369728088378906
# Shape:  (50, 273)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  199
# Incremental:  0.0011641979217529297  Regular:  0.003968000411987305
# Shape:  (50, 274)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  200
# Incremental:  0.0015900135040283203  Regular:  0.0035860538482666016
# Shape:  (50, 275)
# Aab vs Aix:  True
# ---------------------------------
#
# Iteration:  200 (50, 275)   1.2822580337524414 s
#          (50, 50) (50, 50) (50,) (50, 50) (50, 275)
#
# DOWNDATE Aab vs Ai:  True
# Current index:  201
# Incremental:  0.0012259483337402344  Regular:  0.0036649703979492188
# Shape:  (50, 275)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  202
# Incremental:  0.0014030933380126953  Regular:  0.004084110260009766
# Shape:  (50, 276)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  203
# Incremental:  0.0012421607971191406  Regular:  0.004865884780883789
# Shape:  (50, 277)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  204
# Incremental:  0.001168966293334961  Regular:  0.003626108169555664
# Shape:  (50, 278)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  205
# Incremental:  0.001603841781616211  Regular:  0.004987955093383789
# Shape:  (50, 279)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  206
# Incremental:  0.0014848709106445312  Regular:  0.004314899444580078
# Shape:  (50, 280)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  207
# Incremental:  0.0014820098876953125  Regular:  0.0037550926208496094
# Shape:  (50, 281)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  208
# Incremental:  0.0012660026550292969  Regular:  0.004539966583251953
# Shape:  (50, 282)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  209
# Incremental:  0.0012540817260742188  Regular:  0.0042040348052978516
# Shape:  (50, 283)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  210
# Incremental:  0.0012240409851074219  Regular:  0.004058122634887695
# Shape:  (50, 284)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  211
# Incremental:  0.0010938644409179688  Regular:  0.0043201446533203125
# Shape:  (50, 285)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  212
# Incremental:  0.0012998580932617188  Regular:  0.0037398338317871094
# Shape:  (50, 286)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  213
# Incremental:  0.0014317035675048828  Regular:  0.00471806526184082
# Shape:  (50, 287)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  214
# Incremental:  0.0013918876647949219  Regular:  0.003969907760620117
# Shape:  (50, 288)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  215
# Incremental:  0.0015611648559570312  Regular:  0.0037882328033447266
# Shape:  (50, 289)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  216
# Incremental:  0.0013229846954345703  Regular:  0.004738807678222656
# Shape:  (50, 289)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  217
# Incremental:  0.001547098159790039  Regular:  0.0046308040618896484
# Shape:  (50, 290)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  218
# Incremental:  0.0013320446014404297  Regular:  0.004186868667602539
# Shape:  (50, 291)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  219
# Incremental:  0.0012850761413574219  Regular:  0.005300045013427734
# Shape:  (50, 292)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  220
# Incremental:  0.001508951187133789  Regular:  0.0044918060302734375
# Shape:  (50, 293)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  221
# Incremental:  0.001123189926147461  Regular:  0.0038759708404541016
# Shape:  (50, 293)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  222
# Incremental:  0.0014719963073730469  Regular:  0.003756999969482422
# Shape:  (50, 294)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  223
# Incremental:  0.0013189315795898438  Regular:  0.004713296890258789
# Shape:  (50, 295)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  224
# Incremental:  0.001203298568725586  Regular:  0.0041730403900146484
# Shape:  (50, 296)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  225
# Incremental:  0.0011792182922363281  Regular:  0.0046079158782958984
# Shape:  (50, 297)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  226
# Incremental:  0.0010979175567626953  Regular:  0.0039119720458984375
# Shape:  (50, 298)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  227
# Incremental:  0.0011992454528808594  Regular:  0.0039081573486328125
# Shape:  (50, 299)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  228
# Incremental:  0.001207113265991211  Regular:  0.0047149658203125
# Shape:  (50, 300)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  229
# Incremental:  0.0012269020080566406  Regular:  0.0038449764251708984
# Shape:  (50, 301)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  230
# Incremental:  0.0012059211730957031  Regular:  0.0049669742584228516
# Shape:  (50, 302)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  231
# Incremental:  0.0010716915130615234  Regular:  0.0044612884521484375
# Shape:  (50, 302)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  232
# Incremental:  0.0016720294952392578  Regular:  0.004463911056518555
# Shape:  (50, 303)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  233
# Incremental:  0.001528024673461914  Regular:  0.0040891170501708984
# Shape:  (50, 304)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  234
# Incremental:  0.0011818408966064453  Regular:  0.005021095275878906
# Shape:  (50, 305)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  235
# Incremental:  0.0016088485717773438  Regular:  0.0051729679107666016
# Shape:  (50, 306)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  236
# Incremental:  0.0012538433074951172  Regular:  0.004056692123413086
# Shape:  (50, 307)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  237
# Incremental:  0.0011551380157470703  Regular:  0.004336833953857422
# Shape:  (50, 308)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  238
# Incremental:  0.0017580986022949219  Regular:  0.00499725341796875
# Shape:  (50, 309)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  239
# Incremental:  0.001603841781616211  Regular:  0.004518032073974609
# Shape:  (50, 310)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  240
# Incremental:  0.001123666763305664  Regular:  0.0040361881256103516
# Shape:  (50, 311)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  241
# Incremental:  0.0013148784637451172  Regular:  0.004121065139770508
# Shape:  (50, 312)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  242
# Incremental:  0.0012569427490234375  Regular:  0.005430936813354492
# Shape:  (50, 313)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  243
# Incremental:  0.001363992691040039  Regular:  0.004235982894897461
# Shape:  (50, 314)
# Aab vs Aix:  True
# ---------------------------------
# Current index:  244
# Incremental:  0.0012276172637939453  Regular:  0.0050201416015625
# Shape:  (50, 315)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  245
# Incremental:  0.0014438629150390625  Regular:  0.004342079162597656
# Shape:  (50, 316)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  246
# Incremental:  0.0012030601501464844  Regular:  0.0044400691986083984
# Shape:  (50, 316)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  247
# Incremental:  0.0014011859893798828  Regular:  0.004281759262084961
# Shape:  (50, 317)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  248
# Incremental:  0.0013129711151123047  Regular:  0.0042247772216796875
# Shape:  (50, 318)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  249
# Incremental:  0.0012161731719970703  Regular:  0.0041768550872802734
# Shape:  (50, 319)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  250
# Incremental:  0.0012400150299072266  Regular:  0.00426173210144043
# Shape:  (50, 320)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  251
# Incremental:  0.0011968612670898438  Regular:  0.004146099090576172
# Shape:  (50, 321)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  252
# Incremental:  0.0012590885162353516  Regular:  0.004027843475341797
# Shape:  (50, 322)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  253
# Incremental:  0.0016241073608398438  Regular:  0.004324674606323242
# Shape:  (50, 323)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  254
# Incremental:  0.0012857913970947266  Regular:  0.00426173210144043
# Shape:  (50, 324)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  255
# Incremental:  0.0012557506561279297  Regular:  0.004678010940551758
# Shape:  (50, 325)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  256
# Incremental:  0.0013921260833740234  Regular:  0.004419088363647461
# Shape:  (50, 325)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  257
# Incremental:  0.001138925552368164  Regular:  0.004669904708862305
# Shape:  (50, 326)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  258
# Incremental:  0.0014252662658691406  Regular:  0.004670858383178711
# Shape:  (50, 327)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  259
# Incremental:  0.001332998275756836  Regular:  0.004417896270751953
# Shape:  (50, 328)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  260
# Incremental:  0.0013439655303955078  Regular:  0.00494074821472168
# Shape:  (50, 329)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  261
# Incremental:  0.0018277168273925781  Regular:  0.005029916763305664
# Shape:  (50, 329)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  262
# Incremental:  0.0015301704406738281  Regular:  0.0046808719635009766
# Shape:  (50, 330)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  263
# Incremental:  0.0013689994812011719  Regular:  0.005251646041870117
# Shape:  (50, 331)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  264
# Incremental:  0.0014421939849853516  Regular:  0.004761219024658203
# Shape:  (50, 332)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  265
# Incremental:  0.0015041828155517578  Regular:  0.004754304885864258
# Shape:  (50, 333)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  266
# Incremental:  0.0012600421905517578  Regular:  0.004970073699951172
# Shape:  (50, 334)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  267
# Incremental:  0.0017771720886230469  Regular:  0.005208253860473633
# Shape:  (50, 335)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  268
# Incremental:  0.0012509822845458984  Regular:  0.0048410892486572266
# Shape:  (50, 336)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  269
# Incremental:  0.0013217926025390625  Regular:  0.004355907440185547
# Shape:  (50, 337)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  270
# Incremental:  0.0012662410736083984  Regular:  0.0049457550048828125
# Shape:  (50, 338)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  271
# Incremental:  0.0009400844573974609  Regular:  0.0045812129974365234
# Shape:  (50, 338)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  272
# Incremental:  0.0013270378112792969  Regular:  0.004923105239868164
# Shape:  (50, 339)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  273
# Incremental:  0.0013959407806396484  Regular:  0.0051000118255615234
# Shape:  (50, 340)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  274
# Incremental:  0.0012028217315673828  Regular:  0.0047299861907958984
# Shape:  (50, 341)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  275
# Incremental:  0.0012199878692626953  Regular:  0.004618167877197266
# Shape:  (50, 342)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  276
# Incremental:  0.0012552738189697266  Regular:  0.005221128463745117
# Shape:  (50, 342)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  277
# Incremental:  0.0014488697052001953  Regular:  0.004854917526245117
# Shape:  (50, 343)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  278
# Incremental:  0.0013070106506347656  Regular:  0.005248069763183594
# Shape:  (50, 344)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  279
# Incremental:  0.0013611316680908203  Regular:  0.0049059391021728516
# Shape:  (50, 345)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  280
# Incremental:  0.0014688968658447266  Regular:  0.004641056060791016
# Shape:  (50, 346)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  281
# Incremental:  0.0009658336639404297  Regular:  0.004513978958129883
# Shape:  (50, 346)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  282
# Incremental:  0.0016901493072509766  Regular:  0.004528045654296875
# Shape:  (50, 347)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  283
# Incremental:  0.0012507438659667969  Regular:  0.004289150238037109
# Shape:  (50, 348)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  284
# Incremental:  0.0015521049499511719  Regular:  0.00491786003112793
# Shape:  (50, 349)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  285
# Incremental:  0.001294851303100586  Regular:  0.0043430328369140625
# Shape:  (50, 350)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  286
# Incremental:  0.0011591911315917969  Regular:  0.004741191864013672
# Shape:  (50, 350)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  287
# Incremental:  0.001283884048461914  Regular:  0.0045239925384521484
# Shape:  (50, 351)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  288
# Incremental:  0.0013849735260009766  Regular:  0.004846096038818359
# Shape:  (50, 352)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  289
# Incremental:  0.0014841556549072266  Regular:  0.0054340362548828125
# Shape:  (50, 353)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  290
# Incremental:  0.0014109611511230469  Regular:  0.005541086196899414
# Shape:  (50, 354)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  291
# Incremental:  0.0015597343444824219  Regular:  0.004363059997558594
# Shape:  (50, 354)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  292
# Incremental:  0.001445770263671875  Regular:  0.004893302917480469
# Shape:  (50, 355)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  293
# Incremental:  0.0015358924865722656  Regular:  0.0053250789642333984
# Shape:  (50, 356)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  294
# Incremental:  0.0015342235565185547  Regular:  0.004429817199707031
# Shape:  (50, 357)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  295
# Incremental:  0.0012009143829345703  Regular:  0.00450587272644043
# Shape:  (50, 358)
# Aab vs Aix:  True
# ---------------------------------
#
# DOWNDATE Aab vs Ai:  True
# Current index:  296
# Incremental:  0.0009338855743408203  Regular:  0.004265308380126953
# Shape:  (50, 358)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  297
# Incremental:  0.0012969970703125  Regular:  0.00520777702331543
# Shape:  (50, 359)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  298
# Incremental:  0.0014710426330566406  Regular:  0.005012035369873047
# Shape:  (50, 360)
# Aab vs Aix:  True
# ---------------------------------
#
# Current index:  299
# Incremental:  0.0014119148254394531  Regular:  0.0052700042724609375
# Shape:  (50, 361)
# Aab vs Aix:  True
# ---------------------------------
#
# Overall time:  2.15777325630188

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from numpy import arange, pi

# %matplotlib inline 


# function range and actual values
t = arange( -25.0, 25.0, 0.05 )

fnA = np.cos( 2*pi*t ) * np.exp( -1.5*np.abs( np.abs( np.sin( 0.125*pi*t )) ) ) * np.cos( np.abs(t) )
fnB = np.cos( 1.0e-1*pi*t )

# single point of switching mix function (sigmoidal)
mixfnA = 1.0/(1.0+np.exp( -t ))
# multiple alternating switching points (sinusoid) 
mixfnB = (1+np.sin( 0.1*pi*t))/2
# first function ONLY (second function NOT used)
mixfnC = 1-t**0
# second function ONLY (first function NOT used)
mixfnD = t**0
# increasingly fast switching between the two functions
mixfnE = np.sin( 2*pi*(1e-1*t)**2 )

mixfn = mixfnE*(1-mixfnE)*mixfnA*(1-mixfnA)*mixfnE*(1-mixfnB)

fn = (1-mixfn)*fnA + mixfn*fnB



# variance for a normal noise applied to the function
sigma = 1.0e-3
# noised function (normal noise with sigma as specified above)
nfn = fn + sigma*np.random.randn( t.shape[ 0 ], )



# if running in 'adaptive' mode, a sample is used to update the model
# only if the absolute prediction error is above a specified threshold
adaptive = True
errorThreshold = 5.0e-2
# if adaptive mode is 'false' then a percentage of the samples is used
# for training (first percentage * nbSamples, cf. window 'scanner' below)
percentageTraining = 2.5e-1

# response values, actual vs predicted (lresp is for the learnt samples/responses)
resp = []; xresp = []; lresp = [];
# index of the samples that were used as input for learning
lsindx = []



# index and size of the window we will use to scan the data; response offset w.r.t. window
indx = 0; windowSize = 30; respOffset = 1; nbRespValues = 5; maxModelSamples = 150



# number of hidden units (rough ann simulation)
nbHUnits = 10
# initialize a matrix of randow weights (input-hidden layer)
rweights = np.random.randn( windowSize, nbHUnits )
# output weights (that need to be determined, first random)
oweights = np.random.randn( nbHUnits, nbRespValues )



# ann svd for the output layer
annisvd = None



# counters and basic information (time spent training, nb. of samples, etc.)
startt = time.time()

trainingTime = 0
nbTrainingSamples = 0
nbSamples = 0

sampleData = None
sampleDataResponse = None

while indx < t.shape[ 0 ] - (windowSize + respOffset-1 + nbRespValues-1 ):
        
    hlinp = np.dot( nfn[ indx:windowSize+indx ], rweights )
    hlinp = 1.0/( 1.0 + np.exp( -0.1*hlinp ) ) - 0.5
    
    # store the actual response and calculate the predicted response values
    aresponse = nfn[ indx + (windowSize + respOffset-1) : indx + (windowSize + respOffset-1 + nbRespValues) ]
    presponse = np.dot( hlinp.reshape( 1, nbHUnits ), oweights ).reshape( nbRespValues, )
    
    error = ( np.sum((presponse-aresponse)**2) / nbRespValues )**0.5
    
    xresp = np.append( xresp, presponse[ -1 ] )
    resp  = np.append( resp, aresponse[ -1 ] )
    
    
    if sampleData is None:
        sampleData = nfn[ indx:windowSize+indx ]
        sampleDataResponse = aresponse
    else:
        sampleData = np.vstack( (sampleData, nfn[ indx:windowSize+indx ]) )
        sampleDataResponse = np.vstack( (sampleDataResponse, aresponse) )

            
    # no svd has been computed up to now, no prediction can be made
    if annisvd == None:
        X = hlinp.reshape( nbHUnits, 1 )
        U, s, Vt = np.linalg.svd( X, full_matrices=False )
        
        annisvd = iSVD( U, s, Vt, updateVt = True  )        
        lresp = [ aresponse ]
        sampleAdded = True
        
    else:
        
        if (not adaptive and indx < t.shape[ 0 ] * percentageTraining) or (adaptive and error > errorThreshold):
            annisvd.update( hlinp.reshape( nbHUnits, 1 ) )
            lresp = np.vstack( (lresp, aresponse) )                    
            
            if annisvd.Vt.shape[ 1 ] > maxModelSamples:
                annisvd.downdate( 0 )
                lresp = lresp[ 1:, : ]

            
    # updating the output weights - note that the update method adds columns
    # and NOT rows (as it would be expected for Ax = y); the incremental SVD
    # we obtain is thus for A^T - we need however the A^+ (pseudoeinverse of A)
    
    # if A^T = UsV^T (SVD) and knowing that i. (A^T)+ = Vs^{-1}U^T; and (ii) (A^+)^T = (A^T)^+
    # we have that (A^+)^T = Vs^{-1}U^T, following that A^+ = Us^{-1}V^T
    
    # in order to upate the weights, we need to calculate x = A^+ y            
    
    if (not adaptive and indx < t.shape[ 0 ] * percentageTraining) or (adaptive and error > errorThreshold) :

        tstart = time.time()
        nbTrainingSamples = nbTrainingSamples+1

        Ux, sx, Vtx = annisvd.svd()

        nzindx = sx > 0; sx[ nzindx ] = 1.0/sx[ nzindx ]
        oweights = np.dot(
            np.dot( Ux, np.dot( np.diag( sx ), Vtx ) ),
            lresp
        )
        tend = time.time()
        trainingTime = trainingTime + (tend-tstart)
        
        lsindx = np.append( lsindx, t[ indx ] )
    
    nbSamples = nbSamples+1
    indx = indx+1

endt = time.time()
    
print( "Nb of samples:", nbSamples, "(", nbTrainingSamples, "samples used for training )" )
print( "Time:", (endt-startt), "(", trainingTime, "for training )" )
print( "RMSE:", ( np.sum((xresp-resp)**2) / resp.shape[ 0 ] )**0.5 )


def axvlines(xs, **plot_kwargs):
    """
    Draw vertical lines on plot
    :param xs: A scalar, list, or 1D array of horizontal offsets
    :param plot_kwargs: Keyword arguments to be passed to plot
    :return: The plot object corresponding to the lines.
    """
    xs = np.array((xs, ) if np.isscalar(xs) else xs, copy=False)
    lims = plt.gca().get_ylim()
    x_points = np.repeat(xs[:, None], repeats=3, axis=1).flatten()
    y_points = np.repeat(np.array(lims + (np.nan, ))[None, :], repeats=len(xs), axis=0).flatten()
    plot = plt.plot(x_points, y_points, scaley = False, **plot_kwargs)
    return plot


fig = plt.figure( 1, figsize = (20, 6), dpi = 50 )
ax1 = fig.add_subplot( 111 )

ax1.grid( True, color = 'green' )
ax1.set_ylim( (-1.5, 1.5) )

axvlines( lsindx, linewidth=0.5, color='gray', alpha=0.5 )

ax1.plot( t[ windowSize + respOffset-1 + nbRespValues-1: ], np.abs(resp-xresp), 'blue', label = 'Error', alpha = 0.1)
ax1.plot( t, nfn, 'blue', label = 'Noised Fn' )
ax1.plot( t, fn, 'black', label = 'Support Fn') 
ax1.plot( t[ windowSize + respOffset-1 + nbRespValues-1: ], xresp, 'red', label = 'Pred' )

ax1.legend(loc='upper right', frameon=False)

plt.show()
# Out:
# Nb of samples: 966 ( 141 samples used for training )
# Time: 0.10963129997253418 ( 0.005944013595581055 for training )
# RMSE: 0.05833816193991394

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (RBF, Matern, RationalQuadratic,
                                              ExpSineSquared, DotProduct,
                                              ConstantKernel)

kernels = [1.0 * RBF(length_scale=1.0, length_scale_bounds=(1e-3, 100.0)),
           1.0 * RationalQuadratic(length_scale=1.0, alpha=0.1),
           
           1.0 * ExpSineSquared( length_scale=1.0, periodicity=10.0,
                                length_scale_bounds=(0.1, 100.0),
                                periodicity_bounds=(1.0, 1000.0)),
           ConstantKernel(0.1, (0.01, 10.0))
               * (DotProduct(sigma_0=1.0, sigma_0_bounds=(0.0, 10.0)) ** 2),
           1.0 * Matern(length_scale=1.0, length_scale_bounds=(1e-1, 10.0),
                        nu=1.5)]
    
gp = GaussianProcessRegressor( kernel = kernels[ 2 ] + kernels[ 4 ], alpha=1e-10 )

gptstart = time.time()
gp.fit( 
    sampleData[ 0:int(percentageTraining*sampleData.shape[0]), : ], 
    sampleDataResponse[0:int(percentageTraining*sampleData.shape[0])] 
)
gptend = time.time()

gp_response, gp_std = gp.predict( sampleData, return_std=True )


print( "Nb of samples:", percentageTraining*sampleData.shape[0] )
print( "Time:", gptend-gptstart, "for training" )
print( "RMSE:", ( np.sum(( gp_response[ :, -1 ] - resp )**2) / resp.shape[ 0 ] )**0.5 )



fig = plt.figure( 1, figsize = (20, 6), dpi = 50 )
ax1 = fig.add_subplot( 111 )

ax1.grid( True, color = 'green' )
ax1.set_ylim( (-1.5, 1.5) )

ax1.plot( t[ windowSize + respOffset-1 + nbRespValues-1: ], np.abs(resp-gp_response[:, -1]), 'blue', label = 'Error', alpha = 0.1)

ax1.plot( t, fn, 'black', label = 'Support Fn' )
ax1.plot( t, nfn, 'blue', label = 'Noised Fn' )
ax1.plot( t[ windowSize+nbRespValues-1: ], gp_response[ :, nbRespValues-1 ], 'red', label = 'Pred' )


ax1.fill_between( t[ windowSize+nbRespValues-1: ], 
                 gp_response[ :, nbRespValues-1 ] - gp_std, 
                 gp_response[ :, nbRespValues-1 ] + gp_std,
                 alpha=0.2, color='k'
                )

ax1.legend(loc='upper right', frameon=False)

plt.show()
# Out:
# Nb of samples: 241.5
# Time: 0.14127898216247559 for training
# RMSE: 0.06573443854634417

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from numpy import arange, pi

from scipy.signal import savgol_filter

# %matplotlib inline 


# function range and actual values
t = arange( -15.0, 15.0, 0.015 )

fnA = np.cos( 2*pi*t ) * np.exp( -1.5*np.abs( np.abs( np.sin( 0.125*pi*t )) ) ) * np.cos( np.abs(t) )
fnB = np.cos( 1.0e-1*pi*t )

# single point of switching mix function (sigmoidal)
mixfnA = 1.0/(1.0+np.exp( -t ))
# multiple alternating switching points (sinusoid) 
mixfnB = (1+np.sin( 0.1*pi*t))/2
# first function ONLY (second function NOT used)
mixfnC = 1-t**0
# second function ONLY (first function NOT used)
mixfnD = t**0
# increasingly fast switching between the two functions
mixfnE = np.sin( 2*pi*(1e-1*t)**2 )

mixfn = mixfnE*(1-mixfnE)*mixfnA*(1-mixfnA)*mixfnE*(1-mixfnB)

fn = (1-mixfn)*fnA + mixfn*fnB



# variance for a normal noise applied to the function
sigma = 1.0e-2

# noised function (normal noise with sigma as specified above)
nfn = fn + sigma*np.random.randn( t.shape[ 0 ], )



# if running in 'adaptive' mode, a sample is used to update the model
# only if the absolute prediction error is above a specified threshold
adaptive = True
errorThreshold = 5.0e-2
# if adaptive mode is 'false' then a percentage of the samples is used
# for training (first percentage * nbSamples, cf. window 'scanner' below)
percentageTraining = 2.5e-1

# response values, actual vs predicted (lresp is for the learnt samples/responses)
resp = []; xresp = []; xlresp = [];
# index of the samples that were used as input for learning
lsindx = []



# index and size of the window we will use to scan the data; response offset w.r.t. window
nbTimeSteps = 3
indx = 0; windowSize = 2*nbTimeSteps-1; maxModelSamples = 50
windowPerturbation = 5; lastTstampOffset = 5; endingGap = lastTstampOffset + nbTimeSteps*windowPerturbation


# number of hidden units (rough ann simulation)
nbHUnits = 15
# initialize a matrix of randow weights (input-hidden layer)
rweights = np.random.randn( windowSize, nbHUnits )
# output weights (that need to be determined, first random)
oweights = np.random.randn( nbHUnits, 1 )



# ann svd for the output layer
annisvd = None


sampleData = None
sampleDataResponse = None



# counters and basic information (time spent training, nb. of samples, etc.)
startt = time.time()

trainingTime = 0
nbTrainingSamples = 0
nbSamples = 0

predTstamps = []

while indx < t.shape[ 0 ] - nbTimeSteps - endingGap:
    
    # generate a set of index values (cummulative sum, will be monotonically increasing)
    xindx = np.random.randint( 0, windowPerturbation, nbTimeSteps ).reshape( 1, nbTimeSteps )
    xindx = np.sort( xindx ); xindx = np.arange( indx, indx+nbTimeSteps ) + np.cumsum( xindx )
    # offset the last timestamp as to 'simulate' looking to a distant point
    xindx[ -1 ] = xindx[ -1 ] + lastTstampOffset
    
    # values and timestamps (from the noised function and the fixed-frequency timestamps)
    xvalues = nfn[ xindx ].reshape( nbTimeSteps, 1)
    #xtstamp = t[ xindx ].reshape( nbTimeSteps, 1 ) # TIMESTAMP
    xtstamp = (xindx-indx).reshape( nbTimeSteps, 1 ) # OFFSET
    #xtstamp[ 0 ] = t[ xtstamp[0]+indx ] # INSERT TIMESTAMP AT FIRST POSITION
    
    # construct a sample by stacking together the timestamp and the values
    xsample = np.hstack( (xtstamp, xvalues) ).reshape( 1, 2*nbTimeSteps )
    # drop the actual 'last' value from the sample (will be used as response)
    xsample = xsample[ :, :-1 ]
    
    # calculate the predicted value for the previously constructed sample
    xhlinp = np.dot( xsample, rweights )
    xhlinp = 1.0/( 1.0 + np.exp( -0.1*xhlinp ) ) - 0.5
        
    # predicted response
    xpresponse = np.dot( xhlinp.reshape( 1, nbHUnits ), oweights ).reshape( 1, )
    error = np.abs( xpresponse-xvalues[-1] )
    
    xresp = np.append( xresp, xpresponse[ -1 ] )
    resp  = np.append( resp, xvalues[ -1 ] )

    
    if sampleData is None:
        sampleData = xsample
        sampleDataResponse = xpresponse
    else:
        sampleData = np.vstack( (sampleData, xsample ) )
        sampleDataResponse = np.vstack( (sampleDataResponse, xpresponse) )
    
    
    
    #predTstamps = np.append( predTstamps, xtstamp[ -1 ] ) # TIMESTAMP
    predTstamps = np.append( predTstamps, t[ xindx[-1] ] ) # TIMESTAMP WHEN USING GAPS

            
    # no svd has been computed up to now, no prediction can be made
    if annisvd == None:
        
        X = xhlinp.reshape( nbHUnits, 1 )
        U, s, Vt = np.linalg.svd( X, full_matrices=False )
        
        annisvd = iSVD( U, s, Vt, updateVt = True  )        
        xlresp = [ xvalues[ -1 ] ]
        sampleAdded = True
                
    else:
        
        if (not adaptive and indx < t.shape[ 0 ] * percentageTraining) or (adaptive and error > errorThreshold):
            annisvd.update( xhlinp.reshape( nbHUnits, 1 ) )
            xlresp = np.vstack( (xlresp, xvalues[-1]) )                    
            
            if annisvd.Vt.shape[ 1 ] > maxModelSamples:
                try:
                    annisvd.downdate( 0 )
                    xlresp = xlresp[ 1:, : ]
                except:
                    print( "FAILED IN DOWNDATING VIA SVD")
                    
    # updating the output weights - note that the update method adds columns
    # and NOT rows (as it would be expected for Ax = y); the incremental SVD
    # we obtain is thus for A^T - we need however the A^+ (pseudoeinverse of A)
    
    # if A^T = UsV^T (SVD) and knowing that i. (A^T)+ = Vs^{-1}U^T; and (ii) (A^+)^T = (A^T)^+
    # we have that (A^+)^T = Vs^{-1}U^T, following that A^+ = Us^{-1}V^T
    
    # in order to upate the weights, we need to calculate x = A^+ y            
    
    if (not adaptive and indx < t.shape[ 0 ] * percentageTraining) or (adaptive and error > errorThreshold) :

        tstart = time.time()
        nbTrainingSamples = nbTrainingSamples+1

        Ux, sx, Vtx = annisvd.svd()

        nzindx = sx > 0; sx[ nzindx ] = 1.0/sx[ nzindx ]
        oweights = np.dot(
            np.dot( Ux, np.dot( np.diag( sx ), Vtx ) ),
            xlresp
        )
        
        tend = time.time()
        trainingTime = trainingTime + (tend-tstart)
        
        lsindx = np.append( lsindx, t[ indx ] )
    
    nbSamples = nbSamples+1
    indx = indx+1

endt = time.time()
    
print( "Nb of samples:", nbSamples, "(", nbTrainingSamples, "samples used for training )" )
print( "Time:", (endt-startt), "(", trainingTime, "for training )" )
print( "RMSE:", ( np.sum((xresp-resp)**2) / resp.shape[ 0 ] )**0.5 )


def axvlines(xs, **plot_kwargs):
    """
    Draw vertical lines on plot
    :param xs: A scalar, list, or 1D array of horizontal offsets
    :param plot_kwargs: Keyword arguments to be passed to plot
    :return: The plot object corresponding to the lines.
    """
    xs = np.array((xs, ) if np.isscalar(xs) else xs, copy=False)
    lims = plt.gca().get_ylim()
    x_points = np.repeat(xs[:, None], repeats=3, axis=1).flatten()
    y_points = np.repeat(np.array(lims + (np.nan, ))[None, :], repeats=len(xs), axis=0).flatten()
    plot = plt.plot(x_points, y_points, scaley = False, **plot_kwargs)
    return plot


fig = plt.figure( 1, figsize = (20, 6), dpi = 50 )
ax1 = fig.add_subplot( 111 )

ax1.grid( True, color = 'green' )
ax1.set_ylim( (-1.5, 1.5) )

axvlines( lsindx, linewidth=0.5, color='gray', alpha=0.5 )

ax1.plot( predTstamps, np.abs(resp-xresp), 'blue', label = 'Error', alpha = 0.1)
ax1.plot( t, nfn, 'blue', label = 'Noised Fn' )
ax1.plot( t, fn, 'black', label = 'Support Fn') 


ax1.plot( predTstamps, xresp, 'green', label = 'Pred', alpha = 0.5 )
plt.scatter( predTstamps, xresp, color='blue', alpha = 0.2 )

ax1.plot( predTstamps, savgol_filter( xresp, 51, 11, delta=0.015 ), 'red', label = 'FPred', alpha = 0.9 )


ax1.legend(loc='upper right', frameon=False)

plt.show()
# Out:
# Nb of samples: 1977 ( 967 samples used for training )
# Time: 1.1029410362243652 ( 0.04500889778137207 for training )
# RMSE: 0.08996863105551228

# %%
import gplearn as gpl
from gplearn import genetic

def _xexp( x ):
    a = np.exp(x); 
    a[ np.abs(a) > 1e+9 ] = 1e+9
    return a    

        

    
# function_set=['add', 'sub', 'mul', 'div', 'sqrt', 'log', 'abs', 'neg', 'inv', 'max', 'min', 'sin', 'cos', 'tan', xexp ],

        
xexp = gpl.functions.make_function( function = _xexp, name='xexp', arity=1 )

est_gpl = genetic.SymbolicRegressor(population_size=1000,
                           tournament_size=5,
                           function_set=['add', 'sub', 'mul', 'div', xexp ],
                           generations=35, stopping_criteria=0.01,
                           p_crossover=0.65, p_subtree_mutation=0.15,
                           p_hoist_mutation=0.05, p_point_mutation=0.1,
                           max_samples=0.5, metric = 'rmse', verbose=1,
                           parsimony_coefficient=1e-3, random_state=None )

nbSamples = sampleData.shape[ 0 ]
indx = np.arange( 0, int(nbSamples*0.25), 1 )
est_gpl.fit( sampleData[ indx, : ], sampleDataResponse[ indx, -1 ] )

score_gpl = est_gpl.score( sampleData, sampleDataResponse[:,-1] )
pred_gpl = est_gpl.predict( sampleData )


print( "RMSE:", ( np.sum((pred_gpl-sampleDataResponse[:, -1])**2) / pred_gpl.shape[ 0 ] )**0.5 )
# Out:
#     |    Population Average   |             Best Individual              |
# ---- ------------------------- ------------------------------------------ ----------
#  Gen   Length          Fitness   Length          Fitness      OOB Fitness  Time Left
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in exp
#   """
# /anaconda3/lib/python3.6/site-packages/gplearn/functions.py:112: RuntimeWarning: overflow encountered in true_divide
#   return np.where(np.abs(x2) > 0.001, np.divide(x1, x2), 1.)
#    0    19.81 6.465332699595374e+23       10 0.1711815555864117 0.1845630723446272     19.45s
#    1    12.83 159931629.32770765        6 0.15537912447939728 0.19157004604187472     37.12s
#    2    12.82 28120391077483.926        7 0.15389961959602688 0.19460009675187773     44.21s
#    3      9.6 7322301.923228279        3 0.145272804333073 0.18340794248369766     43.05s
#    4     6.85 10139404.495886981        7 0.14433412104141216 0.17727821724230708     39.66s
#    5      5.6 1442021926.1180549        3 0.14597659920241615 0.18284828008541895     36.12s
#    6     4.03 60893086.510499656        3 0.13791420800759538 0.18900352450294777     32.74s
#    7     3.41 23680601.682108697        3 0.14162295762632218 0.1862407015613709     30.20s
#    8     2.99 4084924835078.8477        3 0.1394954726981687 0.18783949036774225     28.18s
#    9      3.5 203480604801421.06        3 0.13960553070306367 0.18775770780986495     26.39s
#   10     3.56 893374340.9974332        5 0.1311274564732951 0.1915041420625168     24.99s
#   11     3.64 633544243.2291337        7 0.12239039672439836 0.1214950755573626     23.68s
#   12     3.82 85500728.17321004        7 0.10104046088501295 0.13975438404282362     22.25s
#   13     3.82 2759491.889898942        7 0.11722518056008013 0.126486045229114     21.07s
#   14     3.87 6692142864.958759       11 0.09455274673607657 0.10242266951336419     20.27s
#   15     4.34 21556598.172252182       11 0.09086040845858231 0.10571192610259283     19.36s
#   16     5.32 3040494.247113098       13 0.07764063811400418 0.10286076008116556     18.68s
#   17     6.48 539377497.5571717       13 0.061063071212024915 0.11307886344221937     18.45s
#   18     7.99 6257922.139218087       21 0.06613350528344679 0.11061086804717328     18.28s
#   19     9.34 4155260.521077064       13 0.06059348539344062 0.1133311852541207     17.72s
#   20    11.21 5678063422710.895       13 0.06370673885797874 0.1120261401428531     17.15s
#   21    11.45 25630980.856517386       13 0.062238160473562766 0.11243637936226857     16.45s
#   22    11.93 1705569.44917993       13 0.06344898405068645 0.11217232757752955     15.77s
#   23    12.37 931304566.1392603       17 0.06763564488695502 0.1087037942600562     14.84s
#   24    12.65 4126304.1235219594       13 0.060140424447118174 0.11398041059122979     13.93s
#   25    13.16 7289311.078439947       13 0.05911238703925978 0.11411070818179017     12.74s
#   26     13.3 9018582.584627982       17 0.059617002078247286 0.11330008124008195     11.50s
#   27    13.15 2955167.375526601       13 0.06172189870011708 0.1127206070072434     10.24s
#   28    13.59 2648158.6722666775       13 0.06370550076331301 0.11161154597856106      8.88s
#   29    13.86 2809171727.304698       13 0.05812517537324506 0.11461671785153522      7.48s
#   30    13.76 360448218364386.25       17 0.059202275914954666 0.11167313408049737      6.05s
#   31    13.02 9376992.014871778       17 0.06217421064500061 0.11191721438848452      4.58s
#   32    13.86 3958483.232876753       17 0.059435574766403154 0.11339536056644563      3.08s
#   33    13.43 4924483.231538041       13 0.06065582956937595 0.11370696984123567      1.57s
#   34    13.56 8321006.37376715       17 0.06043724486708623 0.11109947336026657      0.00s
# RMSE: 0.21739491362231148

# %%
from scipy.signal import savgol_filter


fig = plt.figure( 1, figsize = (20, 6), dpi = 50 )
ax1 = fig.add_subplot( 111 )

ax1.grid( True, color = 'green' )
ax1.set_ylim( (-1.5, 1.5) )

ax1.plot( predTstamps, np.abs(resp-pred_gpl), 'blue', label = 'Error', alpha = 0.1)
ax1.plot( t, nfn, 'blue', label = 'Noised Fn' )
ax1.plot( t, fn, 'black', label = 'Support Fn') 


ax1.plot( predTstamps, pred_gpl, 'green', label = 'Pred', alpha = 0.5 )
ax1.plot( predTstamps, savgol_filter( pred_gpl, 65, 5, delta=0.015 ), 'red', label = 'FPred', alpha = 0.9 )

ax1.legend(loc='upper right', frameon=False)

plt.show()
